# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel('Tourists_without_other.xlsx') #removed 'other' from countries in excel file

# %%
df
# Out:
#          Country    Year  Tourists  Unnamed: 3
# 0     Austrailia  2003.0    7916.0         NaN
# 1     Austrailia  2004.0    9671.0         NaN
# 2     Austrailia  2005.0    7093.0         NaN
# 3     Austrailia  2006.0    8231.0         NaN
# 4     Austrailia  2007.0   12369.0         NaN
# 5     Austrailia  2008.0   13846.0         NaN
# 6     Austrailia  2009.0   15461.0         NaN
# 7     Austrailia  2010.0   16243.0         NaN
# 8     Austrailia  2011.0   19824.0         NaN
# 9     Austrailia  2012.0   22030.0         NaN
# 10    Austrailia  2013.0   20469.0         NaN
# 11    Austrailia  2014.0   24516.0         NaN
# 12    Austrailia  2015.0   18619.0         NaN
# 13    Austrailia  2016.0   25507.0         NaN
# 14    Austrailia  2017.0    3337.0         NaN
# 15       Austria  2003.0    3025.0         NaN
# 16       Austria  2004.0    4341.0         NaN
# 17       Austria  2005.0    3007.0         NaN
# 18       Austria  2006.0    3474.0         NaN
# ...

# %%
df.groupby(by='Year').plot(x='Country', y = 'Tourists', kind='barh')
plt.savefig('countries_over_time.pdf')
